# %%
import pandas as pd
chipo=pd.read_csv('.\chipotle.tsv',delimiter='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'item_p'],
#       dtype='object')

# %%
chipo.groupby('item_name')['quantity'].sum()
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
max(chipo.groupby('item_name')['quantity'].sum())
# Out:
# 761

# %%
chipo.groupby('choice_description')['quantity'].sum()
# Out:
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Beans, [Sour Cream, Salsa, Cheese, Cilantro-Lime Rice, Guacamole]]                                                                                 1
# [Adobo-Marinated and Grilled Chicken, [Sour Cream, Cheese, Cilantro-Lime Rice]]                                                                                                                1
# [Adobo-Marinated and Grilled Chicken]                                                                                                                                                          1
# [Adobo-Marinated and Grilled Steak, [Sour Cream, Salsa, Cheese, Cilantro-Lime Rice, Guacamole]]                                                                                                1
# [Adobo-Marinated and Grilled Steak]                                                                                                                                                            1
# ...

# %%
chipo.quantity.sum()
# Out:
# 4972

# %%
chipo['order_id'].count()
# Out:
# 4622

# %%
chipo['item_p']=chipo['item_price'].str[1:]
chipo.item_p
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#          ...
# 4592    11.75
# 4593    11.75
# 4594    11.75
# 4595     8.75
# 4596     4.45
# 4597     1.25
# 4598     1.50
# 4599     8.75
# 4600     4.45
# 4601     1.25
# 4602     9.25
# 4603     9.25
# 4604     8.75
# 4605     4.45
# 4606     1.25
# 4607    11.75
# 4608    11.25
# 4609     1.25
# 4610    11.75
# 4611    11.25
# 4612     9.25
# 4613     2.15
# 4614     1.50
# 4615     8.75
# 4616     4.45
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# ...

# %%
chipo.item_p=chipo['item_p'].astype(float)
print(chipo['item_p'].dtype)
print('$',chipo.item_p.sum())
# Out:
# float64
# $ 34500.16

# %%
chipo['order_id'].count()
# Out:
# 4622

# %%
print('$',chipo.item_p.sum()/chipo['order_id'].count())
# Out:
# $ 7.464335785374297
